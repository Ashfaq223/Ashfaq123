# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashfaq223/Ashfaq123/blob/main/MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install and Import Libraries**

# %%
# !pip install pymongo pandas
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pymongo-4.17.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.2 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 22.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.17.0

# %% [markdown]
# **Connect to MongoDB Atlas**

# %%
MONGO_URI = "mongodb+srv://ashfaq:azh2230363@cluster0.rcgpnje.mongodb.net/?appName=Cluster0"

# %%
from pymongo import MongoClient

# %%
client = MongoClient(MONGO_URI)

# %%
db = client["northstar_db"]

print("Connected to MongoDB Atlas successfully.")
print("Database: northstar_db")
# Out:
# Connected to MongoDB Atlas successfully.
# Database: northstar_db

# %% [markdown]
# **Libraries**

# %%
import pandas as pd
from pymongo import MongoClient
from pymongo.errors import BulkWriteError
from urllib.parse import quote_plus
import json

print("Libraries loaded.")
# Out:
# Libraries loaded.

# %% [markdown]
# **Drop Existing Collections**

# %%
db["customer_profiles"].drop()
db["app_sessions"].drop()
db["delivery_cases"].drop()

print("Old collections cleared.")
# Out:
# Old collections cleared.

# %% [markdown]
# **Load and Clean the Dataset**

# %%
base_path = "Data set/"

orders     = pd.read_csv(base_path + "8# cleaned_orders.csv")
deliveries = pd.read_csv(base_path + "4# cleaned_deliveries.csv")
complaints = pd.read_csv(base_path + "2# cleaned_complaints.csv")
customers  = pd.read_csv(base_path + "3# cleaned_customers.csv")
drivers    = pd.read_csv(base_path + "5# cleaned_drivers.csv")
vehicles   = pd.read_csv(base_path + "7# cleaned_incidents.csv")
app_events  = pd.read_csv(base_path + "1# cleaned_app_events.csv")
incidents  = pd.read_csv(base_path + "7# cleaned_incidents.csv")

print("Data loaded.")
print("Customers:", len(customers))
print("Orders:", len(orders))
# Out:
# Data loaded.
# Customers: 630
# Orders: 1250

# %%
# Cleaning the zone names

def clean_zone(value):
    if pd.isna(value):
        return value
    value = str(value).strip().lower()
    mapping = {
        "airport":   "Airport",
        "north":     "North",
        "south":     "South",
        "east":      "East",
        "west":      "West",
        "central":   "Central",
        "ctr":       "Central",
        "riverside": "Riverside"
    }
    return mapping.get(value, value.title())

# %%
orders["pickup_zone"]      = orders["pickup_zone"].apply(clean_zone)
orders["dropoff_zone"]     = orders["dropoff_zone"].apply(clean_zone)
customers["home_zone"]     = customers["home_zone"].apply(clean_zone)
app_events["zone_context"] = app_events["zone_context"].apply(clean_zone)

# %%
# Fill the missing values

complaints["compensation_amount"].fillna(0, inplace=True)
customers["loyalty_score"].fillna(customers["loyalty_score"].median(), inplace=True)
app_events["order_id"].fillna("No Order", inplace=True)

print("Data loaded and cleaned.")
# Out:
# Data loaded and cleaned.
# /tmp/ipykernel_3518/3315469502.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   complaints["compensation_amount"].fillna(0, inplace=True)
# /tmp/ipykernel_3518/3315469502.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers["loyalty_score"].fillna(customers["loyalty_score"].median(), inplace=True)
# /tmp/ipykernel_3518/3315469502.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   app_events["order_id"].fillna("No Order", inplace=True)

# %% [markdown]
# **Build Collection 1 : Customer Profiles**
#
# Each document contains a customer record with their orders and complaints embedded as nested arrays. This avoids joins and gives an integrated view of each customer's history in a single document.

# %%
# Faster approach - no slow row by row loop
customer_profiles = []

# Group orders and complaints by customer first
orders_grouped    = orders.groupby("customer_id")
complaints_grouped = complaints.groupby("customer_id")

for _, cust in customers.iterrows():
    cid = cust["customer_id"]

    # Get orders for this customer
    orders_list = []
    if cid in orders_grouped.groups:
        for _, o in orders_grouped.get_group(cid).iterrows():
            orders_list.append({
                "order_id":        o["order_id"],
                "service_type":    o["service_type"],
                "pickup_zone":     o["pickup_zone"],
                "dropoff_zone":    o["dropoff_zone"],
                "priority_level":  o["priority_level"],
                "order_value":     round(float(o["order_value"]), 2),
                "booking_channel": str(o["booking_channel"]),
                "created_at":      str(o["order_created_at"])
            })

    # Get complaints for this customer
    complaints_list = []
    if cid in complaints_grouped.groups:
        for _, c in complaints_grouped.get_group(cid).iterrows():
            complaints_list.append({
                "complaint_id":        c["complaint_id"],
                "order_id":            c["order_id"],
                "complaint_type":      c["complaint_type"],
                "severity":            c["severity"],
                "status":              c["status"],
                "compensation_amount": round(float(c["compensation_amount"]), 2)
            })

    doc = {
        "customer_id":      cid,
        "customer_type":    cust["customer_type"],
        "home_zone":        cust["home_zone"],
        "account_status":   cust["account_status"],
        "loyalty_score":    round(float(cust["loyalty_score"]), 1),
        "total_orders":     len(orders_list),
        "total_complaints": len(complaints_list),
        "orders":           orders_list,
        "complaints":       complaints_list
    }
    customer_profiles.append(doc)

print(f"Documents built: {len(customer_profiles)}")

# Drop and reinsert clean
db["customer_profiles"].drop()
db["customer_profiles"].insert_many(customer_profiles)
print(f"customer_profiles inserted: {db['customer_profiles'].count_documents({})}")
# Out:
# Documents built: 630
# customer_profiles inserted: 630

# %% [markdown]
# **Build Collection 2: App Sessions**
#
# Each delivery document includes the related order summary, driver details, and any incidents that occurred. This gives operations managers a full picture of what happened on each delivery without multiple queries.

# %%
app_sessions = []

for session_id, group in app_events.groupby("session_id"):
    events_list = []
    for _, e in group.iterrows():
        events_list.append({
            "event_id":       e["event_id"],
            "event_type":     e["event_type"],
            "order_id":       e["order_id"],
            "timestamp":      str(e["event_timestamp"]),
            "api_latency_ms": int(e["api_latency_ms"]),
            "success_flag":   int(e["success_flag"])
        })
    doc = {
        "session_id":     session_id,
        "customer_id":    group["customer_id"].iloc[0],
        "device_type":    group["device_type"].iloc[0],
        "zone_context":   group["zone_context"].iloc[0],
        "total_events":   len(events_list),
        "failed_events":  int((group["success_flag"] == 0).sum()),
        "avg_latency_ms": round(float(group["api_latency_ms"].mean()), 1),
        "high_latency":   bool((group["api_latency_ms"] > 800).any()),
        "events":         events_list
    }
    app_sessions.append(doc)

print(f"Documents built: {len(app_sessions)}")

db["app_sessions"].drop()
db["app_sessions"].insert_many(app_sessions)
print(f"app_sessions inserted: {db['app_sessions'].count_documents({})}")
# Out:
# Documents built: 637
# app_sessions inserted: 637

# %% [markdown]
# **Build Collection 3: Delivery Cases**
#
# Each delivery document includes the related order summary, driver details, and any incidents that occurred. This gives operations managers a full picture of what happened on each delivery without multiple queries.

# %%
delivery_cases = []

# Group incidents and drivers beforehand for speed
incidents_grouped = incidents.groupby("delivery_id")
orders_dict       = orders.set_index("order_id").to_dict("index")
drivers_dict      = drivers.set_index("driver_id").to_dict("index")

for _, d in deliveries.iterrows():
    did  = d["delivery_id"]
    oid  = d["order_id"]
    drid = d["driver_id"]

    # Get order info
    order_info = {}
    if oid in orders_dict:
        o = orders_dict[oid]
        order_info = {
            "order_id":       oid,
            "service_type":   o["service_type"],
            "pickup_zone":    o["pickup_zone"],
            "dropoff_zone":   o["dropoff_zone"],
            "priority_level": o["priority_level"],
            "order_value":    round(float(o["order_value"]), 2)
        }

    # Get driver info
    driver_info = {}
    if drid in drivers_dict:
        dr = drivers_dict[drid]
        driver_info = {
            "driver_id":       drid,
            "base_zone":       dr["base_zone"],
            "employment_type": dr["employment_type"],
            "training_score":  float(dr["training_score"]) if pd.notna(dr["training_score"]) else None,
            "driver_rating":   float(dr["driver_rating"]) if pd.notna(dr["driver_rating"]) else None
        }

    # Get incidents
    incidents_list = []
    if did in incidents_grouped.groups:
        for _, i in incidents_grouped.get_group(did).iterrows():
            incidents_list.append({
                "incident_id":       i["incident_id"],
                "incident_type":     i["incident_type"],
                "severity":          i["severity"],
                "resolution_status": i["resolution_status"],
                "resolved_hours":    float(i["resolved_hours"]) if pd.notna(i["resolved_hours"]) else None
            })

    doc = {
        "delivery_id":                 did,
        "delivery_status":             d["delivery_status"],
        "hub_id":                      d["hub_id"],
        "vehicle_id":                  d["vehicle_id"],
        "route_distance_km":           float(d["route_distance_km"]) if pd.notna(d["route_distance_km"]) else None,
        "fuel_or_charge_cost":         round(float(d["fuel_or_charge_cost"]), 2) if pd.notna(d["fuel_or_charge_cost"]) else None,
        "manual_route_override_count": int(d["manual_route_override_count"]) if pd.notna(d["manual_route_override_count"]) else 0,
        "customer_rating":             float(d["customer_rating_post_delivery"]) if pd.notna(d["customer_rating_post_delivery"]) else None,
        "order":                       order_info,
        "driver":                      driver_info,
        "incidents":                   incidents_list,
        "incident_count":              len(incidents_list)
    }
    delivery_cases.append(doc)

print(f"Documents built: {len(delivery_cases)}")

db["delivery_cases"].drop()
db["delivery_cases"].insert_many(delivery_cases)
print(f"delivery_cases inserted: {db['delivery_cases'].count_documents({})}")
# Out:
# Documents built: 936
# delivery_cases inserted: 936

# %% [markdown]
# **Verify Collections**

# %%
print("\n Collection Counts ")
print(f"customer_profiles : {db['customer_profiles'].count_documents({})}")
print(f"app_sessions      : {db['app_sessions'].count_documents({})}")
print(f"delivery_cases    : {db['delivery_cases'].count_documents({})}")
# Out:
#  Collection Counts
# customer_profiles : 630
# app_sessions      : 637
# delivery_cases    : 936

# %%
# M10 - Read sample MongoDB documents

sample_customer = db["customer_profiles"].find_one({}, {"_id": 0})
sample_session = db["app_sessions"].find_one({}, {"_id": 0})
sample_delivery = db["delivery_cases"].find_one({}, {"_id": 0})

print("Sample customer profile:")
print(json.dumps(sample_customer, indent=2, default=str)[:1500])

print("\nSample app session:")
print(json.dumps(sample_session, indent=2, default=str)[:1500])

print("\nSample delivery case:")
print(json.dumps(sample_delivery, indent=2, default=str)[:1500])
# Out:
# Sample customer profile:
# {
#   "customer_id": "C0001",
#   "customer_type": "SME",
#   "home_zone": "North",
#   "account_status": "Active",
#   "loyalty_score": 44.9,
#   "total_orders": 3,
#   "total_complaints": 2,
#   "orders": [
#     {
#       "order_id": "O00007",
#       "service_type": "Business",
#       "pickup_zone": "Central",
#       "dropoff_zone": "Airport",
#       "priority_level": "Low",
#       "order_value": 76.12,
#       "booking_channel": "App",
#       "created_at": "2024-05-05 21:32:00"
#     },
#     {
#       "order_id": "O00666",
#       "service_type": "Parcel",
#       "pickup_zone": "Airport",
#       "dropoff_zone": "Central",
#       "priority_level": "Low",
#       "order_value": 185.32,
#       "booking_channel": "App",
#       "created_at": "2025-08-26 20:17:00"
#     },
#     {
#       "order_id": "O00721",
#       "service_type": "Retail",
#       "pickup_zone": "East",
#       "dropoff_zone": "Central",
#       "priority_level": "Medium",
#       "order_value": 70.79,
#       "booking_channel": "App",
#       "created_at": "2025-02-17 06:36:00"
#     }
#   ],
#   "complaints": [
#     {
#       "complaint_id": "CP0096",
#       "order_id": "O00007",
#       "complaint_type": "AppIssue",
#       "severity": "High",
#       "status": "Resolved",
#       "compensation_amount": 43.9
#     },
#     {
#       "complaint_id": "CP0146",
#       "order_id": "O00666",
#       "complaint_type": "Delay",
#       "severity": "Medium",
#       "status": "Resolved",
#       "compensation_amount": 0.0
#     }
#   ]
# }
#
# Sample app session:
# {
#   "session_id": "S10192",
#   "customer_id": "C0180",
#   "device_type": "Android",
#   "zone_context": "Central",
#   "total_events": 1,
#   "failed_events": 0,
#   "avg_latency_ms": 108.0,
#   "high_latency": false,
#   "events": [
#     {
#       "event_id": "AE00403",
#       "event_type": "payment_retry",
#       "order_id": "O00149",
#       "timestamp": "2025-03-19 09:20:00",
#       "api_latency_ms": 108,
#       "success_flag": 1
#     }
#   ]
# }
#
# Sample delivery case:
# {
#   "delivery_id": "DL00001",
#   "delivery_status": "Failed",
#   "hub_id": "H05",
#   "vehicle_id": "V056",
#   "route_distance_km": 17.26,
#   "fuel_or_charge_cost": 12.05,
#   "manual_route_override_count": 1,
#   "customer_rating": 3.07,
#   "order": {
#     "order_id": "O00938",
#     "service_type": "Business",
#     "pickup_zone": "Central",
#     "dropoff_zone": "Central",
#     "priority_level": "Medium",
#     "order_value": 151.14
#   },
#   "driver": {
#     "driver_id": "D004",
#     "base_zone": "Airport",
#     "employment_type": "PartTime",
#     "training_score": 88.9,
#     "driver_rating": 4.75
#   },
#   "incidents": [
#     {
#       "incident_id": "I0180",
#       "incident_type": "ProofMissing",
#       "severity": "High",
#       "resolution_status": "Open",
#       "resolved_hours": 5.6
#     }
#   ],
#   "incident_count": 1
# }

# %% [markdown]
# **CRUD Operations**
#
# C - Create a new customer profile

# %%
print("\n CREATE: Insert a new customer ")

new_customer = {
    "customer_id":       "C9999",
    "customer_type":     "Consumer",
    "home_zone":         "East",
    "account_status":    "Active",
    "loyalty_score":     72.0,
    "preferred_channel": "App",
    "total_orders":      0,
    "total_complaints":  0,
    "orders":            [],
    "complaints":        []
}

result = db["customer_profiles"].insert_one(new_customer)
print(f"Inserted document ID: {result.inserted_id}")
# Out:
#  CREATE: Insert a new customer
# Inserted document ID: 69fc3a69e7e30c2664138225

# %% [markdown]
# **R** - Read or Find all high severity complaints in customer profiles

# %%
print("\n READ: Customers with High severity complaints ")

high_severity_customers = db["customer_profiles"].find(
    {"complaints.severity": "High"},
    {"customer_id": 1, "customer_type": 1, "home_zone": 1, "total_complaints": 1, "_id": 0}
).limit(5)

for doc in high_severity_customers:
    print(doc)
# Out:
#  READ: Customers with High severity complaints
# {'customer_id': 'C0001', 'customer_type': 'SME', 'home_zone': 'North', 'total_complaints': 2}
# {'customer_id': 'C0004', 'customer_type': 'Consumer', 'home_zone': 'Central', 'total_complaints': 2}
# {'customer_id': 'C0015', 'customer_type': 'SME', 'home_zone': 'South', 'total_complaints': 1}
# {'customer_id': 'C0031', 'customer_type': 'Consumer', 'home_zone': 'South', 'total_complaints': 1}
# {'customer_id': 'C0078', 'customer_type': 'Consumer', 'home_zone': 'East', 'total_complaints': 2}

# %% [markdown]
# **R** - Read or Find failed deliveries with incidents

# %%
print("\n READ: Failed Deliveries with Incidents \n")

failed_with_incidents = db["delivery_cases"].find(
    {
        "delivery_status": "Failed",
        "incident_count":  {"$gt": 0}
    },
    {
        "delivery_id":     1,
        "hub_id":          1,
        "incident_count":  1,
        "order.pickup_zone": 1,
        "_id":             0
    }
).limit(5)

for doc in failed_with_incidents:
    print(doc)
# Out:
#  READ: Failed Deliveries with Incidents
#
# {'delivery_id': 'DL00001', 'hub_id': 'H05', 'order': {'pickup_zone': 'Central'}, 'incident_count': 1}
# {'delivery_id': 'DL00038', 'hub_id': 'H02', 'order': {'pickup_zone': 'South'}, 'incident_count': 1}
# {'delivery_id': 'DL00057', 'hub_id': 'H04', 'order': {'pickup_zone': 'East'}, 'incident_count': 1}
# {'delivery_id': 'DL00068', 'hub_id': 'H08', 'order': {'pickup_zone': 'West'}, 'incident_count': 1}
# {'delivery_id': 'DL00089', 'hub_id': 'H03', 'order': {'pickup_zone': 'West'}, 'incident_count': 1}

# %% [markdown]
# **R** - Read or Find sessions with high latency and failed events

# %%
print("\n READ: App Sessions with High Latency and Failures ")

bad_sessions = db["app_sessions"].find(
    {
        "high_latency":  True,
        "failed_events": {"$gt": 0}
    },
    {
        "session_id":    1,
        "customer_id":   1,
        "device_type":   1,
        "avg_latency_ms": 1,
        "failed_events": 1,
        "_id":           0
    }
).limit(5)

for doc in bad_sessions:
    print(doc)
# Out:
#  READ: App Sessions with High Latency and Failures
# {'session_id': 'S17952', 'customer_id': 'C0509', 'device_type': 'iOS', 'failed_events': 1, 'avg_latency_ms': 1402.0}
# {'session_id': 'S19782', 'customer_id': 'C0451', 'device_type': 'Android', 'failed_events': 1, 'avg_latency_ms': 862.0}
# {'session_id': 'S24008', 'customer_id': 'C0429', 'device_type': 'Web', 'failed_events': 1, 'avg_latency_ms': 998.0}
# {'session_id': 'S36427', 'customer_id': 'C0238', 'device_type': 'Android', 'failed_events': 1, 'avg_latency_ms': 1138.0}

# %% [markdown]
# **U** - Update a customer loyalty score

# %%
print("\n UPDATE: Update loyalty score for C0001 ")

update_result = db["customer_profiles"].update_one(
    {"customer_id": "C0001"},
    {"$set": {"loyalty_score": 95.0}}
)

print(f"Documents matched:  {update_result.matched_count}")
print(f"Documents modified: {update_result.modified_count}")
# Out:
#  UPDATE: Update loyalty score for C0001
# Documents matched:  1
# Documents modified: 1

# %%
# Confirm the update

updated = db["customer_profiles"].find_one(
    {"customer_id": "C0001"},
    {"customer_id": 1, "loyalty_score": 1, "_id": 0}
)
print(f"Updated record: {updated}")
# Out:
# Updated record: {'customer_id': 'C0001', 'loyalty_score': 95.0}

# %%
print("\n UPDATE MANY: Flag North zone delayed deliveries ")

update_many_result = db["delivery_cases"].update_many(
    {
        "delivery_status":   "Delayed",
        "order.pickup_zone": "North"
    },
    {"$set": {"requires_review": True}}
)

print(f"Documents matched:  {update_many_result.matched_count}")
print(f"Documents modified: {update_many_result.modified_count}")
# Out:
#  UPDATE MANY: Flag North zone delayed deliveries
# Documents matched:  21
# Documents modified: 21

# %% [markdown]
# **D** - DELETE : Remove the test customer we created

# %%
print("\n DELETE: Remove test customer C9999 ")

delete_result = db["customer_profiles"].delete_one(
    {"customer_id": "C9999"}
)

print(f"Documents deleted: {delete_result.deleted_count}")

# Confirm deletion

check = db["customer_profiles"].find_one({"customer_id": "C9999"})
print(f"C9999 still exists: {check is not None}")
# Out:
#  DELETE: Remove test customer C9999
# Documents deleted: 1
# C9999 still exists: False

# %% [markdown]
# **Aggregation Pipelines**
#
# Aggregations allow us to run analytics directly inside MongoDB without pulling data into Python first.

# %%
# M13 - Aggregation 2: High-latency app sessions by zone

pipeline_2 = [
    {"$match": {"high_latency": True}},
    {"$group": {
        "_id": "$zone_context",
        "high_latency_sessions": {"$sum": 1},
        "average_latency": {"$avg": "$avg_latency_ms"},
        "failed_events": {"$sum": "$failed_events"}
    }},
    {"$sort": {"high_latency_sessions": -1}}
]

result_2 = list(db["app_sessions"].aggregate(pipeline_2))

print("High-latency app sessions by zone:")
for row in result_2:
    print(row)
# Out:
# High-latency app sessions by zone:
# {'_id': 'Airport', 'high_latency_sessions': 21, 'average_latency': 1159.2380952380952, 'failed_events': 0}
# {'_id': 'Central', 'high_latency_sessions': 14, 'average_latency': 1103.5, 'failed_events': 2}
# {'_id': 'South', 'high_latency_sessions': 6, 'average_latency': 850.5833333333334, 'failed_events': 0}
# {'_id': 'Riverside', 'high_latency_sessions': 5, 'average_latency': 916.0, 'failed_events': 1}
# {'_id': 'West', 'high_latency_sessions': 4, 'average_latency': 943.5, 'failed_events': 1}
# {'_id': 'North', 'high_latency_sessions': 4, 'average_latency': 860.5, 'failed_events': 0}
# {'_id': 'East', 'high_latency_sessions': 3, 'average_latency': 930.6666666666666, 'failed_events': 0}

# %%
# Aggregation 1: Complaint count and avg compensation by zone

print("\n Aggregation 1: Complaints by Home Zone \n")

pipeline1 = [
    {"$unwind": "$complaints"},
    {"$group": {
        "_id":                "$home_zone",
        "total_complaints":   {"$sum": 1},
        "avg_compensation":   {"$avg": "$complaints.compensation_amount"},
        "high_severity_count": {
            "$sum": {
                "$cond": [{"$eq": ["$complaints.severity", "High"]}, 1, 0]
            }
        }
    }},
    {"$sort": {"total_complaints": -1}}
]
# Out:
#  Aggregation 1: Complaints by Home Zone

# %%
# M12 - Aggregation 1: Complaint severity by customer type

pipeline_1 = [
    {"$unwind": "$complaints"},
    {"$group": {
        "_id": {
            "customer_type": "$customer_type",
            "severity": "$complaints.severity"
        },
        "complaint_count": {"$sum": 1},
        "total_compensation": {"$sum": "$complaints.compensation_amount"}
    }},
    {"$sort": {"complaint_count": -1}}
]

result_1 = list(db["customer_profiles"].aggregate(pipeline_1))

print("Complaint severity by customer type:")
for row in result_1:
    print(row)
# Out:
# Complaint severity by customer type:
# {'_id': {'customer_type': 'Consumer', 'severity': 'Medium'}, 'complaint_count': 126, 'total_compensation': 2226.09}
# {'_id': {'customer_type': 'Consumer', 'severity': 'Low'}, 'complaint_count': 48, 'total_compensation': 453.69}
# {'_id': {'customer_type': 'Consumer', 'severity': 'High'}, 'complaint_count': 47, 'total_compensation': 1875.31}
# {'_id': {'customer_type': 'SME', 'severity': 'Medium'}, 'complaint_count': 21, 'total_compensation': 343.13}
# {'_id': {'customer_type': 'Enterprise', 'severity': 'Medium'}, 'complaint_count': 15, 'total_compensation': 236.28}
# {'_id': {'customer_type': 'SME', 'severity': 'Low'}, 'complaint_count': 13, 'total_compensation': 95.4}
# {'_id': {'customer_type': 'SME', 'severity': 'High'}, 'complaint_count': 11, 'total_compensation': 389.63}
# {'_id': {'customer_type': 'Enterprise', 'severity': 'High'}, 'complaint_count': 6, 'total_compensation': 259.2}
# {'_id': {'customer_type': 'Enterprise', 'severity': 'Low'}, 'complaint_count': 4, 'total_compensation': 18.74}

# %%
results1 = list(db["customer_profiles"].aggregate(pipeline1))
for r in results1:
    print(r)
# Out:
# {'_id': 'North', 'total_complaints': 62, 'avg_compensation': 20.508225806451613, 'high_severity_count': 12}
# {'_id': 'Central', 'total_complaints': 53, 'avg_compensation': 19.111509433962265, 'high_severity_count': 11}
# {'_id': 'South', 'total_complaints': 44, 'avg_compensation': 18.077954545454546, 'high_severity_count': 7}
# {'_id': 'Riverside', 'total_complaints': 41, 'avg_compensation': 21.461951219512198, 'high_severity_count': 9}
# {'_id': 'Airport', 'total_complaints': 33, 'avg_compensation': 21.819999999999997, 'high_severity_count': 8}
# {'_id': 'East', 'total_complaints': 30, 'avg_compensation': 23.926, 'high_severity_count': 8}
# {'_id': 'West', 'total_complaints': 28, 'avg_compensation': 17.851428571428574, 'high_severity_count': 9}

# %%
# Aggregation 2: Delivery failure rate by hub

print("\n Aggregation 2: Delivery Failure Rate by Hub \n")

pipeline2 = [
    {"$group": {
        "_id":            "$hub_id",
        "total":          {"$sum": 1},
        "failed":         {"$sum": {"$cond": [{"$eq": ["$delivery_status", "Failed"]}, 1, 0]}},
        "delayed":        {"$sum": {"$cond": [{"$eq": ["$delivery_status", "Delayed"]}, 1, 0]}},
        "avg_cost":       {"$avg": "$fuel_or_charge_cost"},
        "total_overrides": {"$sum": "$manual_route_override_count"}
    }},
    {"$addFields": {
        "failure_rate_pct": {
            "$round": [
                {"$multiply": [
                    {"$divide": [{"$add": ["$failed", "$delayed"]}, "$total"]},
                    100
                ]},
                1
            ]
        }
    }},
    {"$sort": {"failure_rate_pct": -1}}
]
# Out:
#  Aggregation 2: Delivery Failure Rate by Hub

# %%
results2 = list(db["delivery_cases"].aggregate(pipeline2))
for r in results2:
    print(r)
# Out:
# {'_id': 'H06', 'total': 103, 'failed': 15, 'delayed': 27, 'avg_cost': 13.362330097087378, 'total_overrides': 94, 'failure_rate_pct': 40.8}
# {'_id': 'H05', 'total': 113, 'failed': 22, 'delayed': 24, 'avg_cost': 13.569115044247788, 'total_overrides': 106, 'failure_rate_pct': 40.7}
# {'_id': 'H08', 'total': 125, 'failed': 26, 'delayed': 21, 'avg_cost': 11.75208, 'total_overrides': 140, 'failure_rate_pct': 37.6}
# {'_id': 'H07', 'total': 113, 'failed': 14, 'delayed': 25, 'avg_cost': 12.973185840707965, 'total_overrides': 119, 'failure_rate_pct': 34.5}
# {'_id': 'H02', 'total': 105, 'failed': 10, 'delayed': 26, 'avg_cost': 12.533809523809524, 'total_overrides': 97, 'failure_rate_pct': 34.3}
# {'_id': 'H04', 'total': 126, 'failed': 16, 'delayed': 27, 'avg_cost': 13.137222222222222, 'total_overrides': 110, 'failure_rate_pct': 34.1}
# {'_id': 'H01', 'total': 135, 'failed': 17, 'delayed': 26, 'avg_cost': 12.724444444444444, 'total_overrides': 140, 'failure_rate_pct': 31.9}
# {'_id': 'H03', 'total': 116, 'failed': 11, 'delayed': 21, 'avg_cost': 12.621206896551724, 'total_overrides': 103, 'failure_rate_pct': 27.6}

# %%
# Aggregation 3: Average latency and failure rate by device type
print("\n--- Aggregation 3: App Performance by Device Type ---")

pipeline3 = [
    {"$group": {
        "_id":           "$device_type",
        "total_sessions": {"$sum": 1},
        "avg_latency":   {"$avg": "$avg_latency_ms"},
        "total_failures": {"$sum": "$failed_events"},
        "high_latency_sessions": {"$sum": {"$cond": ["$high_latency", 1, 0]}}
    }},
    {"$sort": {"avg_latency": -1}}
]
# Out:
# --- Aggregation 3: App Performance by Device Type ---

# %%
results3 = list(db["app_sessions"].aggregate(pipeline3))
for r in results3:
    print(r)
# Out:
# {'_id': 'Web', 'total_sessions': 91, 'avg_latency': 469.0879120879121, 'total_failures': 6, 'high_latency_sessions': 10}
# {'_id': 'iOS', 'total_sessions': 232, 'avg_latency': 463.92241379310343, 'total_failures': 11, 'high_latency_sessions': 15}
# {'_id': 'Android', 'total_sessions': 314, 'avg_latency': 463.5222929936306, 'total_failures': 21, 'high_latency_sessions': 32}

# %%
# M14 - Aggregation 3: Delivery incidents and route overrides by delivery status

pipeline_3 = [
    {"$group": {
        "_id": "$delivery_status",
        "total_deliveries": {"$sum": 1},
        "total_incidents": {"$sum": "$incident_count"},
        "average_route_distance": {"$avg": "$route_distance_km"},
        "average_route_overrides": {"$avg": "$manual_route_override_count"},
        "average_customer_rating": {"$avg": "$customer_rating"}
    }},
    {"$sort": {"total_incidents": -1}}
]

result_3 = list(db["delivery_cases"].aggregate(pipeline_3))

print("Delivery performance summary by delivery status:")
for row in result_3:
    print(row)
# Out:
# Delivery performance summary by delivery status:
# {'_id': 'OnTime', 'total_deliveries': 608, 'total_incidents': 177, 'average_route_distance': 13.77266447368421, 'average_route_overrides': 0.9276315789473685, 'average_customer_rating': 4.28327302631579}
# {'_id': 'Delayed', 'total_deliveries': 197, 'total_incidents': 50, 'average_route_distance': 14.485279187817259, 'average_route_overrides': 1.0710659898477157, 'average_customer_rating': 3.11497461928934}
# {'_id': 'Failed', 'total_deliveries': 131, 'total_incidents': 32, 'average_route_distance': 13.337862595419848, 'average_route_overrides': 1.0229007633587786, 'average_customer_rating': 3.0493129770992367}
